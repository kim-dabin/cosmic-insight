# %%
import requests

# NASA API와 OpenWeather API 키
NASA_API_KEY = 'ado1gPnvu5em84ZhpZaaX7zb5VLIkRDe7nq5crrH'
OPENWEATHER_API_KEY = '7b0a3a43be59dca5245a8a7fc99396c6'


# OpenWeather API로 서울 날씨 가져오기
def get_seoul_weather():
    lat, lon = 37.5665, 126.9780  # 서울의 위도와 경도
    url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={OPENWEATHER_API_KEY}&units=metric"
    response = requests.get(url)
    return response.json()

# NASA API로 화성 날씨 가져오기
def get_mars_weather():
    url = f"https://api.nasa.gov/insight_weather/?api_key={NASA_API_KEY}&feedtype=json&ver=1.0"
    response = requests.get(url)
    return response.json()

# 서울과 화성 날씨 비교
seoul_weather = get_seoul_weather()
mars_weather = get_mars_weather()
latest_sol = mars_weather['sol_keys'][-1]  # 가장 최근 Sol 사용

print("서울 날씨:")
print(f"온도: {seoul_weather['main']['temp']} °C")
print(f"기압: {seoul_weather['main']['pressure']} hPa")
print()

print("화성 날씨:")
print(f"온도 (평균): {mars_weather[latest_sol]['AT']['av']} °C")

print(f"기압: {mars_weather[latest_sol]['PRE']['av']} Pa")
# Out:
# 서울 날씨:
# 온도: 10.66 °C
# 기압: 1023 hPa
#
# 화성 날씨:
# 온도 (평균): -62.434 °C
# 기압: 743.55 Pa

# %%
import requests

NASA_API_KEY = 'ado1gPnvu5em84ZhpZaaX7zb5VLIkRDe7nq5crrH'

def get_mars_weather():
    url = f"https://api.nasa.gov/insight_weather/?api_key={NASA_API_KEY}&feedtype=json&ver=1.0"
    response = requests.get(url)
    return response.json()

mars_weather = get_mars_weather()
print(mars_weather)
# Out:
# {'675': {'AT': {'av': -62.314, 'ct': 177556, 'mn': -96.872, 'mx': -15.908}, 'First_UTC': '2020-10-19T18:32:20Z', 'HWS': {'av': 7.233, 'ct': 88628, 'mn': 1.051, 'mx': 22.455}, 'Last_UTC': '2020-10-20T19:11:55Z', 'Month_ordinal': 10, 'Northern_season': 'early winter', 'PRE': {'av': 750.563, 'ct': 887776, 'mn': 722.0901, 'mx': 768.791}, 'Season': 'fall', 'Southern_season': 'early summer', 'WD': {'0': {'compass_degrees': 0.0, 'compass_point': 'N', 'compass_right': 0.0, 'compass_up': 1.0, 'ct': 254}, '1': {'compass_degrees': 22.5, 'compass_point': 'NNE', 'compass_right': 0.382683432365, 'compass_up': 0.923879532511, 'ct': 1}, '10': {'compass_degrees': 225.0, 'compass_point': 'SW', 'compass_right': -0.707106781187, 'compass_up': -0.707106781187, 'ct': 8618}, '11': {'compass_degrees': 247.5, 'compass_point': 'WSW', 'compass_right': -0.923879532511, 'compass_up': -0.382683432365, 'ct': 1912}, '12': {'compass_degrees': 270.0, 'compass_point': 'W', 'compass_right': -1.0, 'compass_up': -0.0, 'c
# ...
